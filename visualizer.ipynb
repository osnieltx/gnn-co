# %%
import pandas as pd

# %%
dataset = './experiments/2024-05-14 2025/0/metrics.csv'
data = pd.read_csv(dataset)
data.head()
# Out:
#    epoch  step  test_acc  test_aon  test_mvc_s  train_acc  train_aon  \
# 0      0    49       NaN       NaN         NaN        0.8        0.0
# 1      0    99       NaN       NaN         NaN        0.9        0.0
# 2      0   149       NaN       NaN         NaN        0.8        0.0
# 3      0   199       NaN       NaN         NaN        0.7        0.0
# 4      0   249       NaN       NaN         NaN        1.0        1.0
#
#    train_loss  train_mvc_s  val_acc  val_aon  val_loss  val_mvc_s
# 0    0.441900          6.0      NaN      NaN       NaN        NaN
# 1    0.362043          1.0      NaN      NaN       NaN        NaN
# 2    0.356745          0.0      NaN      NaN       NaN        NaN
# 3    0.572100          7.0      NaN      NaN       NaN        NaN
# 4    0.111825          0.0      NaN      NaN       NaN        NaN

# %%
data.columns
# Out:
# Index(['epoch', 'step', 'test_acc', 'test_aon', 'test_mvc_s', 'train_acc',
#        'train_aon', 'train_loss', 'train_mvc_s', 'val_acc', 'val_aon',
#        'val_loss', 'val_mvc_s'],
#       dtype='object')

# %%
columns = [c for c in data.columns if 'mvc' in c]
data.groupby('epoch').mean()[columns].plot(figsize=(13,5), title='MVC Index')
# Out:
# <Axes: title={'center': 'MVC Index'}, xlabel='epoch'>

# %%
columns = [c for c in data.columns if 'mvc' in c]
data.groupby('epoch').mean()[columns]
# Out:
#        test_mvc_s  train_mvc_s  val_mvc_s
# epoch
# 0             NaN      2.85000     1.1600
# 1             NaN      2.30625     1.1715
# 2             NaN      3.11250     4.9095
# 3             NaN      3.31250     3.4845
# 4             NaN      2.63750     1.2635
# ...           ...          ...        ...
# 59            NaN      2.83125     1.1950
# 60            NaN      2.61875     3.4845
# 61            NaN      3.34375     1.2255
# 62            NaN      2.48750     7.6815
# 63          1.158          NaN        NaN
#
# [64 rows x 3 columns]

# %%
columns = [c for c in data.columns if 'acc' in c]
data.groupby('epoch').mean()[columns].plot(figsize=(13,5), title='Accuracy')
# Out:
# <Axes: title={'center': 'Accuracy'}, xlabel='epoch'>

# %%
columns = [c for c in data.columns if 'aon' in c]
data.groupby('epoch').mean()[columns].plot(figsize=(13,5), title='All or Nothing')
# Out:
# <Axes: title={'center': 'All or Nothing'}, xlabel='epoch'>

# %%
columns = [c for c in data.columns if 'loss' in c]
data.groupby('epoch').mean()[columns].plot(figsize=(13,5), title='Loss')
# Out:
# <Axes: title={'center': 'Loss'}, xlabel='epoch'>

# %%
columns = [c for c in data.columns if 'val' in c]
new_data = data.groupby('epoch').mean()[columns]
new_data = (new_data-new_data.min())/(new_data.max()-new_data.min())
new_data.plot(figsize=(20,8), title='Normalized Validation Metrics')
# Out:
# <Axes: title={'center': 'Normalized Validation Metrics'}, xlabel='epoch'>
